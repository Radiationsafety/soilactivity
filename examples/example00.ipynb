# %% [markdown]
# # example

# %%
from soilactivity import Unfolder
import pandas as pd
import numpy as np

# 1. Загрузка данных (пример)
data = pd.read_csv('../data/measurements.csv') # колонки: x, y, z, dose_rate

# 2. Создание сетки
grid_x = np.linspace(0, 10, 20)
grid_y = np.linspace(0, 10, 20)
grid_z = np.linspace(0, 2, 5)

# 3. Инициализация и запуск
uf = Unfolder(method='mlem', iterations=50, tol=1e-4)
result = uf.unfold(
    data,
    (grid_x, grid_y, grid_z),
    attenuation_coeff=0.1
)

# %%
print(f"Сходимость за {result.solver_info['iterations']} итераций")
result.save_to_file('result_activity.npz')
# Out:
# Сходимость за 2 итераций

# %%
result
# Out:
# UnfoldingResult(activity_3d=array([[[2.02083964e-09, 1.86821586e-09, 1.71698053e-09, ...,
#          8.46320978e-10, 9.67416875e-10, 1.09808936e-09],
#         [1.98551233e-09, 1.82975208e-09, 1.67478605e-09, ...,
#          7.73008599e-10, 8.99443826e-10, 1.03675219e-09],
#         [1.96278560e-09, 1.80489968e-09, 1.64736764e-09, ...,
#          7.21315235e-10, 8.53483105e-10, 9.96222003e-10],
#         ...,
#         [2.83503857e-09, 2.72871831e-09, 2.62786762e-09, ...,
#          2.16475027e-09, 2.21502164e-09, 2.27536112e-09],
#         [2.95296882e-09, 2.85104700e-09, 2.75466617e-09, ...,
#          2.31662144e-09, 2.36372412e-09, 2.42041378e-09],
#         [3.07464186e-09, 2.97688100e-09, 2.88469139e-09, ...,
#          2.46945794e-09, 2.51374524e-09, 2.56716931e-09]],
#
#        [[9.99536011e-30, 9.10907851e-30, 6.69671730e-30, ...,
#          2.50292348e-30, 2.51082735e-30, 1.94200650e-30],
#         [2.41244852e-30, 3.11054977e-30, 3.07354849e-30, ...,
#          5.00104949e-30, 6.53060003e-30, 6.58355202e-30],
#         [5.12822551e-30, 5.41460980e-30, 7.03208079e-30, ...,
#          5.75481873e-30, 5.76065329e-30, 7.52431975e-30],
#         ...,
#         [6.93195541e-31, 6.91099900e-31, 6.35893918e-31, ...,
#          2.92292867e-31, 2.91972886e-31, 2.73344584e-31],
#         [2.82118498e-31, 3.01076529e-31, 3.01037405e-31, ...,
#          5.82042574e-31, 6.27254309e-31, 6.27862779e-31],
#         [5.83597959e-31, 6.44857438e-31, 6.95518903e-31, ...,
#          7.55952020e-31, 7.60763839e-31, 8.21005225e-31]],
#
#        [[8.21179245e-31, 7.61208253e-31, 7.49689815e-31, ...,
#          6.66209330e-31, 6.18169767e-31, 5.51546175e-31],
#         [5.92224193e-31, 5.91407316e-31, 5.49463447e-31, ...,
#          2.69206193e-31, 2.69052378e-31, 2.52833093e-31],
#         [2.56132775e-31, 2.72646197e-31, 2.72748006e-31, ...,
#          5.47439701e-31, 5.90752852e-31, 5.92002951e-31],
#         ...,
#         [3.61809179e-30, 2.84798393e-30, 2.83282218e-30, ...,
#          3.31681440e-30, 2.61330382e-30, 2.48986395e-30],
#         [3.17636720e-30, 3.16648800e-30, 2.47311153e-30, ...,
#          1.40525226e-30, 1.41959012e-30, 1.12925965e-30],
#         [1.06274978e-30, 1.34465946e-30, 1.33362237e-30, ...,
#          3.20116673e-30, 4.26310864e-30, 4.67512700e-30]],
#
#        [[1.11096574e-09, 1.06985731e-09, 1.03107454e-09, ...,
#          9.84939744e-10, 1.02971610e-09, 1.07827431e-09],
#         [1.06634071e-09, 1.02430811e-09, 9.84586212e-10, ...,
#          9.32288996e-10, 9.79350676e-10, 1.03027116e-09],
#         [1.02480211e-09, 9.82083410e-10, 9.41721271e-10, ...,
#          8.83447656e-10, 9.32694396e-10, 9.85972991e-10],
#         ...,
#         [7.81602506e-10, 7.62612078e-10, 7.56137129e-10, ...,
#          9.40982584e-10, 9.84804285e-10, 1.03268738e-09],
#         [8.38263070e-10, 8.11682708e-10, 7.98878570e-10, ...,
#          9.87124143e-10, 1.02952839e-09, 1.07572812e-09],
#         [8.96713103e-10, 8.68511535e-10, 8.51281851e-10, ...,
#          1.03529110e-09, 1.07639531e-09, 1.12106301e-09]]],
#       shape=(4, 19, 19)), grid_x=array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ]), grid_y=array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ]), grid_z=array([0. , 0.5, 1. , 1.5, 2. ]), solver_info={'method': 'mlem', 'iterations': 2, 'final_residual': 2.328217918300129e-06, 'converged': np.True_, 'history': [0.999999999987376, 8.617789854254112e-11]}, uncertainty_3d=None)
